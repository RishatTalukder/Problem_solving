# %%
{2,3} & {3}
# Out:
# {3}

# %%
max({2,3})
# Out:
# 3

# %%
from itertools import combinations  

print(list(combinations([1,2,3], 2)))
# Out:
# [(1, 2), (1, 3), (2, 3)]

# %%
5^7^0
# Out:
# 2

# %%
mat = [[0,1,2],[3,4,5],[6,7,8]]

# %%
zip(*mat)

# %%
list(zip(*mat))[::-1]
# Out:
# [(2, 5, 8), (1, 4, 7), (0, 3, 6)]

# %%
for i in range(4):
    for i in zip(*mat):
        print(i[::-1])
# Out:
# (6, 3, 0)
# (7, 4, 1)
# (8, 5, 2)
# (6, 3, 0)
# (7, 4, 1)
# (8, 5, 2)
# (6, 3, 0)
# (7, 4, 1)
# (8, 5, 2)
# (6, 3, 0)
# (7, 4, 1)
# (8, 5, 2)
